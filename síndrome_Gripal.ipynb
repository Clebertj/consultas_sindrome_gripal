# %%
# Notificações de Síndrome Gripal
# ministerio da saude
# https://opendatasus.saude.gov.br/dataset
import pandas as pd
# %matplotlib inline
import requests

url = "https://elasticsearch-saps.saude.gov.br/desc-esus-notifica-estado-*/_search"

payload={}
headers = {
  'Authorization': 'Basic dXNlci1wdWJsaWMtbm90aWZpY2Fjb2VzOlphNHFOWGR5UU5TYTlZYUE='
}

response = requests.request("POST", url, headers=headers, data=payload)

print(response.text)
# Out:
# {"took":33,"timed_out":false,"_shards":{"total":5,"successful":5,"skipped":0,"failed":0},"hits":{"total":{"value":10000,"relation":"gte"},"max_score":1.0,"hits":[{"_index":"desc-esusve_v6","_type":"_doc","_id":"xoLCpdm5Od","_score":1.0,"_source":{"@version":"1","codigoTriagemPopulacaoEspecifica":null,"sintomas":"Dor de Cabeça, Dor de Garganta, Outros","codigoRecebeuVacina":"1","sexo":"Masculino","codigoDosesVacina":["2","1"],"municipio":"Jijoca de Jericoacoara","dataEncerramento":null,"idade":53,"estrangeiro":null,"municipioIBGE":"2307254","estado":"Ceará","codigoBuscaAtivaAssintomatico":null,"dataNotificacao":"2022-01-17T03:00:56.617Z","dataTesteSorologico":null,"estadoNotificacao":"Ceará","cbo":null,"classificacaoFinal":null,"codigoLocalRealizacaoTestagem":"1","evolucaoCaso":null,"racaCor":"Parda","resultadoTesteSorologicoIgA":null,"dataSegundaDose":"2021-08-13T03:00:00.000Z","testes":[],"resultadoTesteSorologicoIgM":null,"resultadoTesteSorologicoTotais":null,"@timestamp":"2022-01-
# ...

# %%
response
# Out:
# <Response [200]>

# %%
sindrome = response.json()

# %%
sindrome
# Out:
# {'took': 33,
#  'timed_out': False,
#  '_shards': {'total': 5, 'successful': 5, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 10000, 'relation': 'gte'},
#   'max_score': 1.0,
#   'hits': [{'_index': 'desc-esusve_v6',
#     '_type': '_doc',
#     '_id': 'xoLCpdm5Od',
#     '_score': 1.0,
#     '_source': {'@version': '1',
#      'codigoTriagemPopulacaoEspecifica': None,
#      'sintomas': 'Dor de Cabeça, Dor de Garganta, Outros',
#      'codigoRecebeuVacina': '1',
#      'sexo': 'Masculino',
#      'codigoDosesVacina': ['2', '1'],
#      'municipio': 'Jijoca de Jericoacoara',
#      'dataEncerramento': None,
#      'idade': 53,
#      'estrangeiro': None,
#      'municipioIBGE': '2307254',
#      'estado': 'Ceará',
#      'codigoBuscaAtivaAssintomatico': None,
#      'dataNotificacao': '2022-01-17T03:00:56.617Z',
#      'dataTesteSorologico': None,
#      'estadoNotificacao': 'Ceará',
#      'cbo': None,
#      'classificacaoFinal': None,
# ...

# %%
pd.json_normalize(sindrome['hits']['hits'])
# Out:
#            _index _type         _id  _score _source.@version  \
# 0  desc-esusve_v6  _doc  xoLCpdm5Od     1.0                1
# 1  desc-esusve_v6  _doc  1TvqbswcWL     1.0                1
# 2  desc-esusve_v6  _doc  EAhAj6B2W2     1.0                1
# 3  desc-esusve_v6  _doc  vSkwRTrQSA     1.0                1
# 4  desc-esusve_v6  _doc  jBzpoPOJx0     1.0                1
# 5  desc-esusve_v6  _doc  Nt9Z8PNplV     1.0                1
# 6  desc-esusve_v6  _doc  IrEJOCAbE2     1.0                1
# 7  desc-esusve_v6  _doc  PnnZCBnAuo     1.0                1
# 8  desc-esusve_v6  _doc  ChwPO51Oj4     1.0                1
# 9  desc-esusve_v6  _doc  Fwmx4WEOHI     1.0                1
#
#   _source.codigoTriagemPopulacaoEspecifica  \
# 0                                     None
# 1                                     None
# 2                                     None
# 3                                     None
# 4                                     None
# ...

# %%
df
# Out:
#    took  timed_out  _shards.total  _shards.successful  _shards.skipped  \
# 0    33      False              5                   5                0
#
#    _shards.failed  hits.total.value hits.total.relation  hits.max_score  \
# 0               0             10000                 gte             1.0
#
#                                            hits.hits
# 0  [{'_index': 'desc-esusve_v6', '_type': '_doc',...

# %%
df
# Out:
#    took  timed_out  _shards.total  _shards.successful  _shards.skipped  \
# 0    33      False              5                   5                0
#
#    _shards.failed  hits.total.value hits.total.relation  hits.max_score  \
# 0               0             10000                 gte             1.0
#
#                                            hits.hits
# 0  [{'_index': 'desc-esusve_v6', '_type': '_doc',...

# %%
df.dtypes
# Out:
# took                     int64
# timed_out                 bool
# _shards.total            int64
# _shards.successful       int64
# _shards.skipped          int64
# _shards.failed           int64
# hits.total.value         int64
# hits.total.relation     object
# hits.max_score         float64
# hits.hits               object
# dtype: object

# %%
df
# Out:
#    took  timed_out  _shards.total  _shards.successful  _shards.skipped  \
# 0    33      False              5                   5                0
#
#    _shards.failed  hits.total.value hits.total.relation  hits.max_score  \
# 0               0             10000                 gte             1.0
#
#                                            hits.hits
# 0  [{'_index': 'desc-esusve_v6', '_type': '_doc',...

# %%
# describe descreve min, max media
df.describe()
# Out:
#        took  _shards.total  _shards.successful  _shards.skipped  \
# count   1.0            1.0                 1.0              1.0
# mean   33.0            5.0                 5.0              0.0
# std     NaN            NaN                 NaN              NaN
# min    33.0            5.0                 5.0              0.0
# 25%    33.0            5.0                 5.0              0.0
# 50%    33.0            5.0                 5.0              0.0
# 75%    33.0            5.0                 5.0              0.0
# max    33.0            5.0                 5.0              0.0
#
#        _shards.failed  hits.total.value  hits.max_score
# count             1.0               1.0             1.0
# mean              0.0           10000.0             1.0
# std               NaN               NaN             NaN
# min               0.0           10000.0             1.0
# 25%               0.0           10000.0             1.0
# ...

# %%
df['_source.sexo'].value_counts().plot.bar()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '_source.sexo'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df['_source.outrasCondicoes'].value_counts()
# Out:
# HIPERTENSÃO SEM COMPLICAÇÃO    1
# SEM COMORBIDADES               1
# Name: _source.outrasCondicoes, dtype: int64

# %%
df['_source.dataNascimento'].value_counts().plot.barh()
# Out:
# <AxesSubplot:>
